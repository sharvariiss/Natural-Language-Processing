# %%
# Bag of Words:converting text into numerical features

from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# Sample documents
documents = [
    "Data science is fun",
    "NLP is a part of data science",
    "Students learn NLP with Python",
    "Python is useful for data science"
]

# Create CountVectorizer object
vectorizer = CountVectorizer()

# Convert text documents into Bag of Words matrix
bow_matrix = vectorizer.fit_transform(documents)

# Get vocabulary / feature names
feature_names = vectorizer.get_feature_names_out()

# Convert matrix into a readable table
bow_df = pd.DataFrame(
    bow_matrix.toarray(),
    columns=feature_names
)

# Display result
print("Vocabulary:")
print(feature_names)

print("\nBag of Words Matrix:")
print(bow_df)
# Out:
# Vocabulary:
# ['data' 'for' 'fun' 'is' 'learn' 'nlp' 'of' 'part' 'python' 'science'
#  'students' 'useful' 'with']
#
# Bag of Words Matrix:
#    data  for  fun  is  learn  nlp  of  part  python  science  students  \
# 0     1    0    1   1      0    0   0     0       0        1         0
# 1     1    0    0   1      0    1   1     1       0        1         0
# 2     0    0    0   0      1    1   0     0       1        0         1
# 3     1    1    0   1      0    0   0     0       1        1         0
#
#    useful  with
# 0       0     0
# 1       0     0
# 2       0     1
# 3       1     0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd 

# Sample documents
documents = [
    "Data science is fun",
    "NLP is a part of data science",
    "Students learn NLP with Python",
    "Python is useful for data science"
]

# Create TfidfVectorizer object
vectorizer = TfidfVectorizer()
# Convert text documents into TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(documents)

# Get vocabulary / feature names
feature_names = vectorizer.get_feature_names_out()

# Convert matrix into a readable table
tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=feature_names
)

# Display result
print("Vocabulary:")
print(feature_names)

print("\nTF-IDF Matrix:")
print(tfidf_df)
# Out:
# Vocabulary:
# ['data' 'for' 'fun' 'is' 'learn' 'nlp' 'of' 'part' 'python' 'science'
#  'students' 'useful' 'with']
#
# TF-IDF Matrix:
#        data       for       fun        is     learn       nlp        of  \
# 0  0.428175  0.000000  0.670819  0.428175  0.000000  0.000000  0.000000
# 1  0.325562  0.000000  0.000000  0.325562  0.000000  0.402134  0.510056
# 2  0.000000  0.000000  0.000000  0.000000  0.485461  0.382743  0.000000
# 3  0.325562  0.510056  0.000000  0.325562  0.000000  0.000000  0.000000
#
#        part    python   science  students    useful      with
# 0  0.000000  0.000000  0.428175  0.000000  0.000000  0.000000
# 1  0.510056  0.000000  0.325562  0.000000  0.000000  0.000000
# 2  0.000000  0.382743  0.000000  0.485461  0.000000  0.485461
# 3  0.000000  0.402134  0.325562  0.000000  0.510056  0.000000

# %%
# common words
